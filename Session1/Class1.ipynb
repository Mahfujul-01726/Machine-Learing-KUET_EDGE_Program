# %%
a=input("Enter a number:")
b=input("Enter another number:")
c=a+b

d=int(a)+int(b)
e="kuet"
print(c)
print("f"Sum of (a) and (b) = (c)"d)
print(type(e))
# Out:
# 5454
# 108
# <class 'str'>

# %%
a=int(input("Enter a number:"))
b=int(input("Enter another number:"))
c=a+b

print(c)
print(f"Sum of {a} and {b} = {c}")
# Out:
# 108
# Sum of 54 and 54 = 108

# %%
a = int(input("Enter a number:"))
b = int(input("Enter another number:"))
c = a + b

print(c)
print("Sum of", a, "and", b, "=", c)
# Out:
# 108
# Sum of 54 and 54 = 108

# %%
a = int(input("Enter a number:"))
b = int(input("Enter another number:"))
c = a + b

print(c)
print("sum of " +str(a)+" and "+ str(b)+ " = "+str(c))
# Out:
# 108
# sum of 54 and 54 = 108

# %% [markdown]
# # Celsius to Fahrenheit converting

# %%
c=int(input("Enter the number for celsius:"))
f=c*(9/5)+32

print("Farenheit number is:", f)
# Out:
# Farenheit number is: 89.6

# %%
a = int(input("Enter the first value: "))
b = int(input("Enter the second value: "))

print((a % b != 0) and (a > 20))
# Out:
# False

# %%
a = int(input("Enter the first value: "))
b=(a>20) and (a%5==0) and (a%3==0)
print(b)
# Out:
# Enter the first value: 15
# False

# %%
a=int(input("Enter a number: "))
b= a/3

print(round(b, 2))
# Out:
# Enter a number: 15
# 5.0

# %%
a=input("Enter a str : ")
b=input("Enter a str : ")
c=a+b
print(c)
# Out:
# Enter a str : hello
# Enter a str : kuet
# hellokuet

# %%
t_seconds=int(input("Enter a number: "))

hr=t_seconds//3600

re_seconds=t_seconds%3600

min=re_seconds//60

seconds=re_seconds%60

print(f"{t_seconds} seconds = {hr} hours, {min} minutes, and {seconds} seconds.")
# Out:
# Enter a number: 3701
# 3701 seconds = 1 hours, 1 minutes, and 41 seconds.
